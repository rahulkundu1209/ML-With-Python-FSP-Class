# %%
# %matplotlib inline
import pandas
import numpy as np

# %%
dfs = pandas.read_excel("SampleData.xlsx")
dfs
# Out:
#     Unnamed: 0                                            Address  \
# 0            1  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1            2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2            3                                               R380
# 3            4                           Holmes HEPA Air Purifier
# 4            5  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# ..         ...                                                ...
# 94          95              Linden® 12" Wall Clock With Oak Frame
# 95          96                                         Newell 326
# 96          97                       Prismacolor Color Pencil Set
# 97          98                         Xerox Blank Computer Paper
# 98          99                                    600 Series Flip
#
#                Name  SomeValue  SomeOtherValue  MoreRandomValues    DD1  \
# 0      Barry French        293        457.8100            208.16  68.02
# ...

# %%
df = pandas.read_csv('gapminder.tsv', sep='\t')
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
#first five rows
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
#last five rows
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (99, 10)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
print(df['country'])
print(df['country'])
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
country_df = df['country']
country_df.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
subset = df[['country', 'continent', 'year']]
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
subset = df.iloc[:, [4, 5]]
subset.head()
# Out:
#         pop   gdpPercap
# 0   8425333  779.445314
# 1   9240934  820.853030
# 2  10267083  853.100710
# 3  11537966  836.197138
# 4  13079460  739.981106

# %%
subset = df.iloc[:, range(2, 6)]
subset.head()
# Out:
#    year  lifeExp       pop   gdpPercap
# 0  1952   28.801   8425333  779.445314
# 1  1957   30.332   9240934  820.853030
# 2  1962   31.997  10267083  853.100710
# 3  1967   34.020  11537966  836.197138
# 4  1972   36.088  13079460  739.981106

# %%
subset = df.iloc[:, range(1, 6, 2)]
subset.head()
# Out:
#   continent  lifeExp   gdpPercap
# 0      Asia   28.801  779.445314
# 1      Asia   30.332  820.853030
# 2      Asia   31.997  853.100710
# 3      Asia   34.020  836.197138
# 4      Asia   36.088  739.981106

# %%
df_firstrow = df.loc[0]
df_firstrow
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.loc[df.shape[0]-2]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2002
# lifeExp          39.989
# pop            11926563
# gdpPercap    672.038623
# Name: 1702, dtype: object

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
data = {'first_name' : ["Meena", 'Sudhir', 'Kumar'],
        'age' : [23, 48, 16],
        'city' : ['Mumbai', 'Boston', 'Sydney']}
df_x = pandas.DataFrame(data, columns=['first_name', 'age', 'city'])
print(df_x)
# Out:
#   first_name  age    city
# 0      Meena   23  Mumbai
# 1     Sudhir   48  Boston
# 2      Kumar   16  Sydney

# %%
city_to_country = {'Mumbai':'India', 'Sydney':'Australia', 'Boston':'USA'}
print(city_to_country)
# Out:
# {'Mumbai': 'India', 'Sydney': 'Australia', 'Boston': 'USA'}

# %%
df_x['country'] = df_x['city'].map(city_to_country)
df_x
# Out:
#   first_name  age    city    country
# 0      Meena   23  Mumbai      India
# 1     Sudhir   48  Boston        USA
# 2      Kumar   16  Sydney  Australia

# %%
dfs2 = pandas.read_excel("DesignThinkingGroups.xlsx")
dfs2
# Out:
#     Group No      Roll No                   Name                     Topic
# 0        1.0  13031122005             Rishav Raj        Telemedicine Kiosk
# 1        NaN  13031122028             Tushar Raj                       NaN
# 2        NaN  13031122013           Aditya Kumar                       NaN
# 3        NaN  13031122027         Sushmita Ghosh                       NaN
# 4        2.0  13031122015            Rahul Kundu                       NaN
# 5        NaN  13031122010      Preet Kumar Singh                       NaN
# 6        NaN  13031122021        Snehaswis Malik                       NaN
# 7        NaN  13031122029             Utasab Das                       NaN
# 8        NaN  13031122014   Piyush Prakhar Singh                       NaN
# 9        3.0  13031122024          Srija Chandra             Mental Health
# 10       NaN  13031122030  Sananda Roy Chowdhury                       NaN
# ...
